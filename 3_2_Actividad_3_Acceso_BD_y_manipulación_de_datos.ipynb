# %% [markdown]
# <a href="https://colab.research.google.com/github/A01795331/estefania/blob/main/3_2_Actividad_3_Acceso_BD_y_manipulaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Primera parte

# %%
import sqlalchemy as sqla
from sqlalchemy import text  # Agregar importación de text

# Instalar las bibliotecas necesarias
# !pip install sqlalchemy pymysql

try:
    # 1 Crear el engine y  connect
    db = sqla.create_engine(
        'mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.157.52:3306/classicmodels',
        pool_recycle=3600
    )
    conn = db.connect()

    # 2 Consulta SQL para obtener información de las líneas de productos
    query_product_lines = text("SELECT * FROM productlines")
    result = conn.execute(query_product_lines)
    for row in result.fetchall():
      print(row)
      print()

    # 3 Consulta SQL para obtener empleados ordenados por nombre
    query_employees = text("SELECT * FROM employees ORDER BY lastName, firstName")
    result = conn.execute(query_employees)
    for row in result.fetchall():
       print(row)
       print()

    # 4 Consulta SQL para obtener los países con oficinas
    query_countries_with_offices = text("SELECT DISTINCT country FROM offices")
    result = conn.execute(query_countries_with_offices)
    for row in result.fetchall():
      print(row[0])

    # 5 Consulta SQL para obtener nombre y teléfono de clientes de Nueva York
    query_customers_nyc = text("SELECT customerName, phone FROM customers WHERE city = 'NYC'")
    result = conn.execute(query_customers_nyc)
    for row in result.fetchall():
       print(row)
       print()

    # 6 Consulta SQL para obtener código y nombre de productos de 'Gearbox Collectibles' con menos de 1000 unidades en stock
    query_gearbox_products = text(
    "SELECT productCode, productName "
    "FROM products "
    "WHERE productVendor = 'Gearbox Collectibles' AND quantityInStock < 1000"
    )
    result = conn.execute(query_gearbox_products)
    for row in result.fetchall():
       print(row)
       print()

    # 7 Consulta SQL para obtener los tres productos más caros
    query_top_prices = text(
    "SELECT productCode, productName, buyPrice "
    "FROM products "
    "ORDER BY buyPrice DESC "
    "LIMIT 3"
    )
    result = conn.execute(query_top_prices)
    for row in result.fetchall():
      print(row)
      print()

    # 8 Consulta SQL para obtener la cantidad de productos por línea de producto
    query_products_per_line = text(
        "SELECT productLine, COUNT(*) as productCount "
        "FROM products "
        "GROUP BY productLine"
    )
    result = conn.execute(query_products_per_line)
    for row in result.fetchall():
        print(f"Product Line: {row[0]}, Product Count: {row[1]}")
        print()

    # 9 Consulta SQL para obtener la cantidad de empleados por país
    query_employees_per_country = text(
        "SELECT o.country, COUNT(e.employeeNumber) as employeeCount "
        "FROM employees e "
        "JOIN offices o ON e.officeCode = o.officeCode "
        "GROUP BY o.country"
    )
    result = conn.execute(query_employees_per_country)
    for row in result.fetchall():
        print(f"Country: {row[0]}, Employee Count: {row[1]}")
        print()

    # 10 Consulta SQL para obtener el promedio de los pagos por cada cliente de España
    query_avg_payments_per_customer_spain = text(
        "SELECT c.customerName, AVG(p.amount) as averagePayment "
        "FROM customers c "
        "JOIN payments p ON c.customerNumber = p.customerNumber "
        "WHERE c.country = 'Spain' "
        "GROUP BY c.customerNumber"
    )
    result = conn.execute(query_avg_payments_per_customer_spain)
    for row in result.fetchall():
        print(f"Customer: {row[0]}, Average Payment: {row[1]:.2f}")
        print()

finally:
    # Cerrar la conexión en el bloque finally para asegurarse de que se cierre incluso si hay un error.
    if conn:
        conn.close()
# Out:
# ...
# ('Classic Cars', 'Attention car enthusiasts: Make your wildest car ownership dreams come true. Whether you are looking for classic muscle cars, dream sports cars or mo ... (437 characters truncated) ... cles. All models include a certificate of authenticity from their manufacturers and come fully assembled and ready for display in the home or office.', None, None)
#
# ('Motorcycles', 'Our motorcycles are state of the art replicas of classic as well as contemporary motorcycle legends such as Harley Davidson, Ducati and Vespa. Models ... (297 characters truncated) ...  out-of-production vehicles. All models come fully assembled and ready for display in the home or office. Most include a certificate of authenticity.', None, None)
#
# ...

# %%
import sqlalchemy as sqla
import pandas as pd

# Instalar las bibliotecas necesarias
# !pip install sqlalchemy pymysql

try:
    # 1 Crear el engine y conectar
    db = sqla.create_engine(
        'mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.157.52:3306/classicmodels',
        pool_recycle=3600
    )
    conn = db.connect()

    # 2 Consulta SQL para obtener información de las líneas de productos
    query_product_lines = text("SELECT * FROM productlines")
    df_product_lines = pd.read_sql_query(query_product_lines, conn)
    print("2. Product Lines:")
    print(df_product_lines)
    print()

    # 3 Consulta SQL para obtener empleados ordenados por nombre
    query_employees = text("SELECT * FROM employees ORDER BY lastName, firstName")
    df_employees = pd.read_sql_query(query_employees, conn)
    print("3. Employees:")
    print(df_employees)
    print()

    # 4 Consulta SQL para obtener los países con oficinas
    query_countries_with_offices = text("SELECT DISTINCT country FROM offices")
    df_countries_with_offices = pd.read_sql_query(query_countries_with_offices, conn)
    print("4. Countries with Offices:")
    print(df_countries_with_offices)
    print()

    # 5 Consulta SQL para obtener nombre y teléfono de clientes de Nueva York
    query_customers_nyc = text("SELECT customerName, phone FROM customers WHERE city = 'NYC'")
    df_customers_nyc = pd.read_sql_query(query_customers_nyc, conn)
    print("5. Customers in NYC:")
    print(df_customers_nyc)
    print()

    # 6 Consulta SQL para obtener código y nombre de productos de 'Gearbox Collectibles' con menos de 1000 unidades en stock
    query_gearbox_products = text(
        "SELECT productCode, productName "
        "FROM products "
        "WHERE productVendor = 'Gearbox Collectibles' AND quantityInStock < 1000"
    )
    df_gearbox_products = pd.read_sql_query(query_gearbox_products, conn)
    print("6. Gearbox Products with Less Than 1000 Units in Stock:")
    print(df_gearbox_products)
    print()

    # 7 Consulta SQL para obtener los tres productos más caros
    query_top_prices = text(
        "SELECT productCode, productName, buyPrice "
        "FROM products "
        "ORDER BY buyPrice DESC "
        "LIMIT 3"
    )
    df_top_prices = pd.read_sql_query(query_top_prices, conn)
    print("7. Top 3 Most Expensive Products:")
    print(df_top_prices)
    print()

    # 8 Consulta SQL para obtener la cantidad de productos por línea de producto
    query_products_per_line = text(
        "SELECT productLine, COUNT(*) as productCount "
        "FROM products "
        "GROUP BY productLine"
    )
    df_products_per_line = pd.read_sql_query(query_products_per_line, conn)
    print("8. Products Per Product Line:")
    print(df_products_per_line)
    print()

    # 9 Consulta SQL para obtener la cantidad de empleados por país
    query_employees_per_country = text(
        "SELECT o.country, COUNT(e.employeeNumber) as employeeCount "
        "FROM employees e "
        "JOIN offices o ON e.officeCode = o.officeCode "
        "GROUP BY o.country"
    )
    df_employees_per_country = pd.read_sql_query(query_employees_per_country, conn)
    print("9. Employees Per Country:")
    print(df_employees_per_country)
    print()

    # 10 Consulta SQL para obtener el promedio de los pagos por cada cliente de España
    query_avg_payments_per_customer_spain = text(
        "SELECT c.customerName, AVG(p.amount) as averagePayment "
        "FROM customers c "
        "JOIN payments p ON c.customerNumber = p.customerNumber "
        "WHERE c.country = 'Spain' "
        "GROUP BY c.customerNumber"
    )
    df_avg_payments_per_customer_spain = pd.read_sql_query(query_avg_payments_per_customer_spain, conn)
    print("10. Average Payments Per Customer in Spain:")
    print(df_avg_payments_per_customer_spain)
    print()

finally:
    # Cerrar la conexión en el bloque finally para asegurarse de que se cierre incluso si hay un error.
    if conn:
        conn.close()
# Out:
# ...
# 2. Product Lines:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None
#
# 3. Employees:
#     employeeNumber   lastName firstName extension  \
# 0             1102     Bondur    Gerard     x5408
# 1             1337     Bondur      Loui     x6493
# ...

# %%
# Instalar las bibliotecas necesarias
# !pip install firebase-admin pandas

# Configurar la conexión a Firestore
import firebase_admin
from firebase_admin import credentials, firestore

cred = credentials.Certificate('veterinary.json')

# Verificar si la aplicación ya está inicializada antes de intentar inicializarla
if not firebase_admin._apps:
    firebase_admin.initialize_app(cred)

db = firestore.client()

# Leer la colección PET_OWNER y mostrar en un DataFrame
import pandas as pd

# Leer la colección PET_OWNER
pet_owner_collection = db.collection('PET_OWNER')
pet_owner_documents = pet_owner_collection.get()

# Crear una lista de diccionarios con los datos
data_list = []
for doc in pet_owner_documents:
    data = doc.to_dict()
    data['id'] = doc.id
    data_list.append(data)

# Convertir la lista a un DataFrame
df_pet_owner = pd.DataFrame(data_list)

# Seleccionar y reorganizar las columnas según el orden solicitado
df_pet_owner = df_pet_owner[['id', 'ownerLastName', 'email', 'phone', 'ownerFirstName']]

# Mostrar el DataFrame
print(df_pet_owner)
# Out:
# ...
#                      id ownerLastName                        email  \
# 0  0D6yFSs2eu4nYwf2dnQ0        Taylor                         None
# 1  98357ufgjmWUxjnAuzbz         Trent    miles.trent@somewhere.com
# 2  AFtZincSZxjC4Mcxf9Pf         Frier      liz.frier@somewhere.com
# 3  GYDixDwHjMyihjL8TmsM      Mayberry                         None
# 4  IpxTuB6FILhwQFcspLws         Downs  'marcha.downs@somewhere.com
# 5  QoXBfS1JdRp6BqgLzaAz       Roberts                         None
# 6  eUtZ44lPRbSHXX04EDp7        Melnik   nigel.melnik@somewhere.com
# 7  n2GG9rlfGOmE0P4TcU0T         James  richard.james@somewhere.com
# 8  pDlJlul8EJXO8FBJvFkN        Rogers     jim.rogers@somewhere.com
# 9  tAlJ74xQ7tT4TUHwZgmH        Keenan    mary.keenan@somewhere.com
#
#           phone ownerFirstName
# 0  555-454-3465            Sam
# 1          None          Miles
# 2  555-537-6543            Liz
# 3  555-454-1243          Jenny
# 4  555-537-8765         Marsha
# 5  555-454-2354            Ken
# ...
